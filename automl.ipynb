# %%
from autoviz.AutoViz_Class import AutoViz_Class
import pandas as pd

# AutoViz 객체 생성
AV = AutoViz_Class()

# 예시 데이터셋 로드
df_x = pd.read_csv('X_train_data.csv')
df_y = pd.read_csv('data/y_train_data.csv')
df = pd.concat([X_train, y_train])

# AutoViz 실행: 데이터 프레임을 입력으로 받아 자동으로 시각화
df_visualized = AV.AutoViz(
    filename="", 
    depVar="상태",  # 종속 변수 (타겟 변수)
    dfte=df,  
    verbose=1,
    max_rows_analyzed=df.shape[0],
    max_cols_analyzed=df.shape[1],
)
# Out:
# Shape of your Data Set loaded: (3992, 15)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  6
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  6
#     Number of Numeric-Boolean Columns =  2
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     14 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...

# %%
import pandas as pd

X_train = pd.read_csv('dog_data/X_train_data.csv')
X_test = pd.read_csv('dog_data/X_test_data.csv')
y_train = pd.read_csv('dog_data/y_train_data.csv')
y_test = pd.read_csv('dog_data/y_test_data.csv')

# %%
from lazypredict.Supervised import LazyClassifier

model = LazyClassifier(verbose=0, ignore_warnings=False, predictions=True)
models, predictions = model.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  19%|█▉        | 6/31 [00:00<00:00, 30.79it/s]
# ROC AUC couldn't be calculated for AdaBoostClassifier
# multi_class must be in ('ovo', 'ovr')
# ROC AUC couldn't be calculated for BaggingClassifier
# multi_class must be in ('ovo', 'ovr')
# ROC AUC couldn't be calculated for BernoulliNB
# multi_class must be in ('ovo', 'ovr')
# ROC AUC couldn't be calculated for CalibratedClassifierCV
# multi_class must be in ('ovo', 'ovr')
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
# ROC AUC couldn't be calculated for DecisionTreeClassifier
# multi_class must be in ('ovo', 'ovr')
# ROC AUC couldn't be calculated for DummyClassifier
# multi_class must be in ('ovo', 'ovr')
# ROC AUC couldn't be calculated for ExtraTreeClassifier
# multi_class must be in ('ovo', 'ovr')
#  42%|████▏     | 13/31 [00:00<00:00, 24.46it/s]
# ROC AUC couldn't be calculated for ExtraTreesClassifier
# multi_class must be in ('ovo', 'ovr')
# ...

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1996, 14)
# (1996, 1)
# (500, 14)
# (500, 1)

# %%
print(X_train.isnull().sum())
print(y_train.isnull().sum())
# Out:
# 품종           0
# 색            0
# 무게(Kg)       0
# 나이           0
# 성별_미상        0
# 성별_수컷        0
# 성별_암컷        0
# 중성화유무_미상     0
# 중성화유무_아니오    0
# 중성화유무_예      0
# 칩등록여부        0
# 성격           0
# 건강           0
# 보유물건         0
# dtype: int64
# 상태    0
# dtype: int64

# %%
X_test['성별_미상'].astype('boolean')
X_test['성별_수컷'].astype('boolean')
X_test['성별_암컷'].astype('boolean')
X_test['중성화유무_미상'].astype('boolean')
X_test['중성화유무_아니오'].astype('boolean')
X_test['중성화유무_예'].astype('boolean')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25      True
# 26     False
# 27     False
# 28      True
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41      True
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
X_train['성별_미상'].astype('boolean')
X_train['성별_수컷'].astype('boolean')
X_train['성별_암컷'].astype('boolean')
X_train['중성화유무_미상'].astype('boolean')
X_train['중성화유무_아니오'].astype('boolean')
X_train['중성화유무_예'].astype('boolean')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1991    False
# 1992    False
# 1993    False
# 1994     True
# 1995     True
# Name: 중성화유무_예, Length: 1996, dtype: boolean
